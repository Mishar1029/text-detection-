# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import fetch_mldata
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-a0a094dc61de> in <module>
# ----> 1 import matplotlib.pyplot as plt
#       2 import numpy as np
#       3 from sklearn.datasets import fetch_mldata
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
mnist =fetch_mldata(dataname-"MNIST original")

# %%
x=mnist['data']
y=mnist['target']

# %%
print(x.dtype, ,y.dtype)
print(x.shape, y.shape)

# %%
def plot_images(images, labels):
        n_cols=min(5,len(images))
        n_rows=len(images)
        fig=plt.figure(figsize=(0,0))
        for i in range (n_rows*n_cols):
                sp=fig.add_subplot(n_rows,n_cols,i+1)
                plt.axis("off")
                plt.imshow(images[i],cmap=plt.cm.gray)
                sp.set_title(labels[i])
        plt.show()
        
#lets plot some numbers random 
p=np.random.permutation(len(x))
p=p[:20]
plot_images(x[p].reshape(-1,28,28),y[p])

# %%
y=y.astype("int32")
x=x/255.0

# %%
x.min(), x.max()

# %%
from sklearn.model_selection import train_split
train_x, test_x,train_y,test_y=train_test_split(x,y)

# %%
train_x.shape, test_x.shape

# %%
from sklearn.navie_bayes import MultimonialNB
cls=MultinomialNB()
cls.fit(train_x,train_y)

# %%
cls.score(test_x,test_y)

# %%
from sklearn.matrics import classification_report
predicts=cls.predict(test_x)
print(classification_report(test_y,predicts))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-8f6c0c4d0731> in <module>
# ----> 1 from sklearn.matrics import classification_report
#       2 predicts=cls.predict(test_x)
#       3 print(classification_report(test_y,predicts))
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
p=np.random.permutation(len(test_x))
p=p[:20]
plot_images(test_x[p].reshape(-1,28,28),predicts[p])
